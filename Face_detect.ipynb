# %%
import cv2
import dlib
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %%
os.chdir('C:/Projects/Face Detection/')

# %%
pwd
# Out:
# 'C:\\Projects\\Face Detection'

# %%
image=cv2.imread('Data Set\\people1.jpg')
display(image.shape)
# Out:
# (1280, 1920, 3)

# %%
plt.imshow(image)
plt.show()

# %%
print(image)
# Out:
# [[[ 91 103 107]
#   [102 114 118]
#   [ 92 107 110]
#   ...
#   [187 192 193]
#   [186 191 192]
#   [185 190 191]]
#
#  [[ 93 105 109]
#   [ 97 109 113]
#   [ 95 110 113]
#   ...
#   [187 192 193]
#   [186 191 192]
#   [185 190 191]]
#
#  [[ 96 111 114]
#   [ 96 111 114]
#   [102 117 120]
#   ...
#   [186 191 192]
#   [185 190 191]
#   [184 189 190]]
#
#  ...
#
#  [[ 48  43  40]
#   [ 46  41  38]
#   [ 44  39  36]
#   ...
#   [251 248 244]
#   [252 247 244]
#   [251 246 243]]
#
#  [[ 55  49  44]
#   [ 53  47  42]
#   [ 49  43  38]
#   ...
#   [251 248 244]
#   [252 247 244]
#   [252 247 244]]
#
#  [[ 56  50  45]
#   [ 54  48  43]
#   [ 50  44  39]
#   ...
#   [252 249 245]
#   [253 248 245]
#   [253 248 245]]]

# %%
img_rgb=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)
plt.show()

# %%
cv2.imshow('',image)
cv2.waitKey(10000)
cv2.destroyAllWindows()

# %%
image=cv2.resize(image,(800,600))
print(image.shape)
# Out:
# (600, 800, 3)

# %%
cv2.imshow('',image)
cv2.waitKey(10000)
cv2.destroyAllWindows()

# %%
image_gray=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
cv2.imshow('',image_gray)
cv2.waitKey(10000)
cv2.destroyAllWindows()

# %%
display(image_gray.shape)
# Out:
# (600, 800)

# %%
face_detector=cv2.CascadeClassifier('Cascades\\haarcascade_frontalface_default.xml')
display(face_detector)
# Out:
# < cv2.CascadeClassifier 0000019CB33D45D0>

# %%
detections=face_detector.detectMultiScale(image_gray)
display(detections)
# Out:
# array([[390, 323,  56,  56],
#        [677,  72,  68,  68],
#        [115, 124,  53,  53],
#        [387, 233,  73,  73],
#        [475, 123,  59,  59],
#        [ 92, 239,  66,  66]])

# %%
display(len(detections))
# Out:
# 6

# %%
x=387
y=233
w=73
h=73
cv2.rectangle(image_gray,(x,y),(x+w,y+h),(0,255,255),5)
cv2.imshow('',image_gray)
cv2.waitKey(10000)
cv2.destroyAllWindows()

# %%
for (x, y, w, h) in detections:
  #print (x, y, w, h)
  cv2.rectangle(image_gray, (x, y), (x + w, y + h), (0,255,255), 5)
cv2.imshow('', image_gray)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()

# %%
image = cv2.imread('Data Set\\people1.jpg')
image = cv2.resize(image, (800, 600)) # Resize image
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
detections = face_detector.detectMultiScale(image_gray, scaleFactor = 1.09)
display (detections)
for (x, y, w, h) in detections:
    cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,0), 5)
cv2.imshow('',image)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()
# Out:
# array([[386, 232,  74,  74],
#        [678,  74,  65,  65],
#        [113, 122,  56,  56],
#        [475, 122,  60,  60],
#        [ 90, 238,  69,  69]])

# %%
image = cv2.imread('Data Set\\people2.jpg')
cv2.imshow('',image)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()

# %%
image = cv2.imread('Data Set\\people2.jpg')
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
detections = face_detector.detectMultiScale(image_gray, scaleFactor = 1.09)
display (detections)
for (x, y, w, h) in detections:
    print(w, h)
    cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,0), 2)
cv2.imshow('',image)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()
# Out:
# array([[692, 153,  44,  44],
#        [424,  32,  46,  46],
#        [168,  35,  50,  50],
#        [663,  83,  43,  43],
#        [ 91,  81,  50,  50],
#        [600,  61,  49,  49],
#        [324,  49,  45,  45],
#        [907,  63,  50,  50],
#        [235,  45,  51,  51],
#        [479,  69,  47,  47],
#        [380,  53,  54,  54],
#        [825,  90,  51,  51],
#        [718, 101,  44,  44],
#        [461, 367,  33,  33],
#        [462, 378,  27,  27]])
# 44 44
# 46 46
# 50 50
# 43 43
# 50 50
# 49 49
# 45 45
# 50 50
# 51 51
# 47 47
# 54 54
# 51 51
# 44 44
# 33 33
# 27 27

# %%
image = cv2.imread('Data Set\\people2.jpg')

image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
detections = face_detector.detectMultiScale (image_gray, scaleFactor = 1.2,minNeighbors=7)
display (detections)
for (x, y, w, h) in detections:
    print(w, h)
    cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,0), 2)
cv2.imshow('',image)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()
# Out:
# array([[424,  31,  47,  47],
#        [168,  35,  49,  49],
#        [662,  83,  44,  44],
#        [906,  63,  51,  51],
#        [480,  70,  47,  47],
#        [ 91,  81,  51,  51],
#        [321,  48,  47,  47],
#        [825,  91,  51,  51],
#        [234,  46,  50,  50],
#        [380,  54,  52,  52],
#        [600,  60,  49,  49],
#        [717, 100,  46,  46]])
# 47 47
# 49 49
# 44 44
# 51 51
# 47 47
# 51 51
# 47 47
# 51 51
# 50 50
# 52 52
# 49 49
# 46 46

# %%
image = cv2.imread('Data Set\\people2.jpg')
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
detections = face_detector.detectMultiScale (image_gray, scaleFactor = 1.2,
                                            minNeighbors=7,minSize=(20,20), maxSize=(100,100))
display (detections)
for (x, y, w, h) in detections:
    print(w, h)
    cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,0), 2)
cv2.imshow('',image)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()
# Out:
# array([[424,  31,  47,  47],
#        [168,  35,  49,  49],
#        [662,  83,  44,  44],
#        [321,  48,  47,  47],
#        [906,  63,  51,  51],
#        [480,  70,  47,  47],
#        [ 91,  81,  51,  51],
#        [234,  46,  50,  50],
#        [380,  54,  52,  52],
#        [825,  91,  51,  51],
#        [600,  60,  49,  49],
#        [717, 100,  46,  46]])
# 47 47
# 49 49
# 44 44
# 47 47
# 51 51
# 47 47
# 51 51
# 50 50
# 52 52
# 51 51
# 49 49
# 46 46

# %%
face_detector_hog = dlib.get_frontal_face_detector()
detections = face_detector_hog(image, 1)

# %%
display (len(detections))
display (detections)

# %%
for face in detections:
  l, t, r, b = face.left(), face.top(), face.right(), face.bottom()
  cv2.rectangle(image, (l, t), (r, b), (0, 255, 255), 2)
cv2.imshow('',image)
cv2.waitKey(30000)
plt.show()
cv2.destroyAllWindows()
